# %% [raw]
# This code analyzes open-comment responses from medium, senior, and very senior civil servants. It begins by producing a histogram of word counts for responses, where only responses with 4 or more words are considered valid. The code then calculates the number of respondents with at least one valid response and those without. Subsequently, it explores differences between these groups based on demographic variables and concludes by examining how responses to the variable BACKSLIDING_2 differ between those who provided open comments and those who did not.

# %% [markdown]
# ### Histogram of word counts distribution (only open comments with 4 or more words considered)

# %% [markdown]
# ### Number of respondents who answered at least one open question and One of those who did not answer any

# %%
# Out:
# Number of respondents with at least one comment above 3 words: 183
# Number of respondents with no comments or all comments 3 words or fewer: 211

# %% [markdown]
# ### Contigency tables for gender, age, tenure, ministry, education, nationality and religiousity

# %%
# Out:
# Contingency Table for gender:
# Note: 'False' represents respondents who did NOT provide any comments, 'True' represents respondents who provided at least one comment.
# +----------+---------+--------+-----------------+----------------+
# | gender   |   False |   True |   False_percent |   True_percent |
# +==========+=========+========+=================+================+
# | female   |     111 |    106 |         51.1521 |        48.8479 |
# +----------+---------+--------+-----------------+----------------+
# | male     |     100 |     77 |         56.4972 |        43.5028 |
# +----------+---------+--------+-----------------+----------------+
#
# Contingency Table for age:
# Note: 'False' represents respondents who did NOT provide any comments, 'True' represents respondents who provided at least one comment.
# +-------+---------+--------+-----------------+----------------+
# | age   |   False |   True |   False_percent |   True_percent |
# ...

# %% [markdown]
# ### Chi-Square Test for Assessing Differences in gender, age, tenure, ministry, education, nationality and religiousity between respondents with open comments and those without open comments

# %%
# Out:
# Statistical Test Results:
#       Variable        Test  Statistic   p-value  Significant
# 0          age  Chi-square   7.068231  0.132326        False
# 1       gender  Chi-square   0.915136  0.338755        False
# 2       tenure  Chi-square   7.054000  0.133062        False
# 3     ministry  Chi-square  24.187159  0.565264        False
# 4    education  Chi-square   4.453562  0.348089        False
# 5  nationality  Chi-square   0.269793  0.603470        False
# 6  religiosity  Chi-square   4.057179  0.541213        False

# %% [markdown]
# ### T-Test for testing the difference in BACKSLIDING_2 between respondents with open comments and those without open comments

# %%
# Out:
# T-test results:
# T-statistic: 1.93100274983747
# P-value: 0.054283294790578314
# There is no significant difference in BACKSLIDING_2 between the two groups.

# %% [markdown]
# ### Histogram of differences in BACKSLIDING_2 between respondents with open comments and those without open comments
